# %%
# python notebook for Make Your Own Neural Network
# code for a 3-layer neural network, and code for learning the MNIST dataset
# (c) Tariq Rashid, 2016
# license is GPLv2

# %%
# first, install imageio if not already installed ~~ AI 가 추가함
# %pip install imageio

# helper to load data from PNG image files
import imageio.v3
# glob helps select multiple files using patterns
import glob

# %%
import numpy
# library for plotting arrays
import matplotlib.pyplot

# %%
# our own image test data set
our_own_dataset = []

# %%
# page 237 of the book shows how to load a single image file
#image_file_name = 'my_own_images/2828_my_own_3.png'

# helper to load data from PNG image files
# import imageio.v3
# glob helps select multiple files using patterns
# import glob

for image_file_name in glob.glob('my_own_images/2828_my_own_?.png'): #glob 함수는 패턴 매칭을 통해 여러 파일을 선택하는 데 사용됩니다.
    print ("loading ... ", image_file_name)
    # use the filename to set the correct label
    label = int(image_file_name[-5:-4])
    # load image data from png files into an array
    img_array = imageio.v3.imread(image_file_name, mode='F') #imageio.v3.imread 함수는 PNG 이미지 파일을 읽어들이고, mode='F' 옵션은 이미지를 부동 소수점 배열로 로드합니다.
    # reshape from 28x28 to list of 784 values, invert values
    img_data  = 255.0 - img_array.reshape(784)
    # then scale data to range from 0.01 to 1.0
    img_data = (img_data / 255.0 * 0.99) + 0.01
    print("최소값 img_data min: ", numpy.min(img_data))
    print("최대값 img_data max: ", numpy.max(img_data))
    # append label and image data  to test data set
    record = numpy.append(label,img_data)
    print("추가된 label,img_data : ", record)
    our_own_dataset.append(record)
    pass
# Out:
# loading ...  my_own_images/2828_my_own_3.png
# 최소값 img_data min:  0.01
# 최대값 img_data max:  1.0
# 추가된 label,img_data :  [3.         0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
# ...

# %%
matplotlib.pyplot.imshow(our_own_dataset[0][1:].reshape(28,28), cmap='Greys', interpolation='None')

# %%
print(our_own_dataset[0])
print("추가해서 테스트",our_own_dataset[0][3])
# Out:
# [3.         0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
# ...

# %%
# 통합 버젼
# python notebook for Make Your Own Neural Network
# code for a 3-layer neural network, and code for learning the MNIST dataset
# (c) Tariq Rashid, 2016
# license is GPLv2

# first, install imageio if not already installed ~~ AI 가 추가함
# %pip install imageio

# helper to load data from PNG image files
import imageio.v3
# glob helps select multiple files using patterns
import glob
import numpy
# library for plotting arrays
import matplotlib.pyplot

# our own image test data set
our_own_dataset = []

#숫자 0~9 까지 이미지 파일 불러오기 확인 ~~
print ("*****",glob.glob('my_own_images/2828_my_own_?.png'))

for image_file_name in glob.glob('my_own_images/2828_my_own_?.png'):
    print ("loading ... ", image_file_name)
    print ("로딩중 ... ", image_file_name)
    
    # use the filename to set the correct label
    label = int(image_file_name[-5:-4])
    
    print ("*** 이미지 파일 이름은 ", image_file_name)
    print ("*** 라벨은 ", label)
    
    # load image data from png files into an array
    img_array = imageio.v3.imread(image_file_name, mode='F')
    
    # reshape from 28x28 to list of 784 values, invert values
    img_data  = 255.0 - img_array.reshape(784)
    
    # then scale data to range from 0.01 to 1.0
    img_data = (img_data / 255.0 * 0.99) + 0.01
    
    print("*** numpy.min(img_data) : ",numpy.min(img_data))
    print("*** numpy.max(img_data) : ",numpy.max(img_data))
    
    # append label and image data  to test data set
    record = numpy.append(label,img_data)
    print("*** record : ",record)
    our_own_dataset.append(record)
    pass

# plot the first image in the dataset to verify 데이터셋을 이미지로 시각화 ~~
matplotlib.pyplot.imshow(our_own_dataset[0][1:].reshape(28,28), cmap='Greys', interpolation='None')

print("*** our_own_dataset[0] : ",our_own_dataset[0])
print("*** 추가해서 테스트 : ",our_own_dataset[0][3])
# Out:
# ***** ['my_own_images/2828_my_own_3.png', 'my_own_images/2828_my_own_2.png', 'my_own_images/2828_my_own_5.png', 'my_own_images/2828_my_own_4.png', 'my_own_images/2828_my_own_6.png']
# loading ...  my_own_images/2828_my_own_3.png
# 로딩중 ...  my_own_images/2828_my_own_3.png
# *** 이미지 파일 이름은  my_own_images/2828_my_own_3.png
# *** 라벨은  3
# *** numpy.min(img_data) :  0.01
# *** numpy.max(img_data) :  1.0
# *** record :  [3.         0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
#  0.01       0.01       0.01       0.01       0.01       0.01
# ...
