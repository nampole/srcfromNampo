# %%
print("Hello, World!")
print("Welcome to Python programming.")
print("This is a simple script to demonstrate printing in Python.")
print("You can print multiple lines of text using the print() function.")
print("Feel free to modify this code and experiment with it!")
print("Goodbye, World!")
x=7/3
type(x)
# Out:
# Hello, World!
# Welcome to Python programming.
# This is a simple script to demonstrate printing in Python.
# You can print multiple lines of text using the print() function.
# Feel free to modify this code and experiment with it!
# Goodbye, World!
# float
