# %% [markdown]
# # 케라스로 만드는 회귀 예제
#
# 매사추세츠 보스턴 지역의 주택 가격 예측하기

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rickiepark/dl-illustrated/blob/master/notebooks/9-3.regression_in_keras.ipynb)

# %% [markdown]
# #### 라이브러리를 적재합니다.

# %%
import numpy as np
from tensorflow.keras.datasets import boston_housing
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout 
from tensorflow.keras.layers import BatchNormalization
# Out:
# 2026-01-27 15:51:41.731805: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# #### 데이터를 적재합니다.

# %%
(X_train, y_train), (X_valid, y_valid) = boston_housing.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57026/57026 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step

# %%
X_train.shape
# Out:
# (404, 13)

# %%
X_valid.shape
# Out:
# (102, 13)

# %%
X_train[0]
# Out:
# array([  1.23247,   0.     ,   8.14   ,   0.     ,   0.538  ,   6.142  ,
#         91.7    ,   3.9769 ,   4.     , 307.     ,  21.     , 396.9    ,
#         18.72   ])

# %%
y_train[0]
# Out:
# 15.2

# %% [markdown]
# #### 신경망을 만듭니다.

# %%
model = Sequential()

model.add(Dense(32, input_dim=13, activation='relu'))
model.add(BatchNormalization())

model.add(Dense(16, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Dense(1, activation='linear'))
# Out:
# /Users/ijaegu/.local/lib/python3.9/site-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 16)             │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,185 (4.63 KB)
#  Trainable params: 1,089 (4.25 KB)
#  Non-trainable params: 96 (384.00 B)

# %% [markdown]
# #### 모델을 설정합니다.

# %%
model.compile(loss='mean_squared_error', optimizer='adam')

# %% [markdown]
# #### 훈련!

# %%
model.fit(X_train, y_train, 
          batch_size=8, epochs=32, verbose=1, 
          validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 614.3676 - val_loss: 653.5616
# Epoch 2/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 597.0190 - val_loss: 605.7876
# Epoch 3/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 548.3031 - val_loss: 577.9075
# Epoch 4/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 516.3624 - val_loss: 541.6506
# Epoch 5/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 524.1331 - val_loss: 510.5238
# Epoch 6/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 537.7584 - val_loss: 460.1153
# Epoch 7/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 409.8617 - val_loss: 331.6745
# Epoch 8/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 456.9783 - val_loss: 293.3017
# Epoch 9/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 376.7735 - val_loss: 340.4591
# Epoch 10/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 333.1978 - val_loss: 318.9279
# Epoch 11/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 327.7334 - val_loss: 254.6623
# Epoch 12/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 200.3946 - val_loss: 283.5380
# Epoch 13/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 194.1586 - val_loss: 297.8046
# Epoch 14/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 175.6491 - val_loss: 163.5243
# Epoch 15/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 137.7861 - val_loss: 86.7962
# Epoch 16/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 116.5279 - val_loss: 97.7462
# Epoch 17/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 93.6129 - val_loss: 72.1988
# Epoch 18/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 76.2594 - val_loss: 150.7887
# Epoch 19/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 58.0842 - val_loss: 41.2680
# Epoch 20/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 60.5362 - val_loss: 31.6971
# Epoch 21/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 60.8338 - val_loss: 114.9678
# Epoch 22/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 60.1393 - val_loss: 36.3536
# Epoch 23/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 41.7860 - val_loss: 40.3060
# Epoch 24/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 44.7794 - val_loss: 41.8441
# Epoch 25/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 37.2643 - val_loss: 30.5383
# Epoch 26/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 46.3193 - val_loss: 41.4513
# Epoch 27/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 44.6875 - val_loss: 31.3087
# Epoch 28/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 38.1916 - val_loss: 23.7947
# Epoch 29/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 40.7703 - val_loss: 22.2537
# Epoch 30/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 53.0395 - val_loss: 34.8282
# Epoch 31/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 36.7859 - val_loss: 34.7990
# Epoch 32/32
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 32.2944 - val_loss: 39.1058

# %%
X_valid[42]
# Out:
# array([  9.32909,   0.     ,  18.1    ,   0.     ,   0.713  ,   6.185  ,
#         98.7    ,   2.2616 ,  24.     , 666.     ,  20.2    , 396.9    ,
#         18.13   ])

# %%
y_valid[42]
# Out:
# 14.1

# %%
model.predict(np.reshape(X_valid[42], [1, 13]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step
# array([[21.143892]], dtype=float32)
