# %% [markdown]
# # 가중치 초기화

# %% [markdown]
# 이 노트북에서는 가중치 초기화가 층의 출력에 어떤 영향을 미치는지 알아 봅니다.

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rickiepark/dl-illustrated/blob/master/notebooks/9-1.weight_initialization.ipynb)

# %% [markdown]
# #### 라이브러리를 적재합니다.

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.initializers import Zeros, RandomNormal, glorot_normal, glorot_uniform
# Out:
# 2026-01-27 14:02:39.241873: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# #### 뉴런의 개수를 지정합니다.

# %%
n_input = 784
n_dense = 256

# %% [markdown]
# #### 절편의 초깃값을 지정합니다.

# %%
b_init = Zeros()

# %% [markdown]
# #### 가중치 초기화를 선택합니다.

# %%
# w_init = RandomNormal(stddev=1.0)
# w_init = glorot_normal()
w_init = glorot_uniform()

# %% [markdown]
# #### 신경망을 만듭니다.

# %%
model = Sequential()
model.add(Dense(n_dense, 
                input_dim=n_input,
                kernel_initializer=w_init,
                bias_initializer=b_init))
model.add(Activation('sigmoid'))
# model.add(Activation('tanh'))
# model.add(Activation('relu'))

# %% [markdown]
# #### 랜덤한 *x* 값을 생성합니다.

# %%
x = np.random.random((1,n_input))

# %% [markdown]
# #### 신경망의 정방향 계산을 수행합니다.

# %%
a = model.predict(x)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step

# %%
a
# Out:
# array([[0.51552576, 0.5445506 , 0.5513721 , 0.5234125 , 0.47719067,
#         0.14426652, 0.62450325, 0.19384192, 0.21646722, 0.413261  ,
#         0.45091474, 0.44827464, 0.71172297, 0.24673505, 0.6295878 ,
#         0.6326426 , 0.6619896 , 0.41376445, 0.29206562, 0.44122064,
#         0.59333855, 0.33407366, 0.37416357, 0.4247416 , 0.55448747,
#         0.6817228 , 0.45762056, 0.48052433, 0.16178562, 0.48132595,
#         0.5778527 , 0.6054258 , 0.4770555 , 0.66433036, 0.58902603,
#         0.55407256, 0.6304008 , 0.22092982, 0.4806835 , 0.1792032 ,
#         0.59005547, 0.33027482, 0.51719594, 0.37139636, 0.4289305 ,
#         0.2097253 , 0.59370196, 0.3215671 , 0.2811097 , 0.68587565,
#         0.5655743 , 0.44542986, 0.62843364, 0.7639241 , 0.66338825,
#         0.6004178 , 0.38676846, 0.25256312, 0.29226938, 0.67770785,
#         0.58964837, 0.63039505, 0.1316914 , 0.32772535, 0.7589259 ,
#         0.31320378, 0.66563904, 0.48635972, 0.42739943, 0.6121274 ,
#         0.21658394, 0.68285984, 0.47297108, 0.28716597, 0.27664515,
#         0.7804121 , 0.49768534, 0.2304089 , 0.67691934, 0.28738987,
#         0.6558493 , 0.6123074 , 0.46388268, 0.61681736, 0.3985926 ,
#         0.52230793, 0.8182325 , 0.40180254, 0.49842805, 0.4575805 ,
#         0.6248435 , 0.41347352, 0.5776896 , 0.43604735, 0.45545608,
