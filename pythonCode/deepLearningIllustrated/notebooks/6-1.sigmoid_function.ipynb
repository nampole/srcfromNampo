# %% [markdown]
# # 시그모이드 활성화 함수

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/rickiepark/dl-illustrated/blob/master/notebooks/6-1.sigmoid_function.ipynb)

# %%
from math import e

# %%
def sigmoid(z):
    print('*** sigmoid 함수 시행됨 >>> ',1/(1+e**-z))
    return 1/(1+e**-z)

# %%
sigmoid(1.5)
sigmoid(-10)
# Out:
# *** sigmoid 함수 시행됨 >>>  0.8175744761936437
# *** sigmoid 함수 시행됨 >>>  4.539786870243442e-05
# 4.539786870243442e-05

# %%
sigmoid(10000)
# Out:
# 1.0

# %%
sigmoid(-1)
# Out:
# 0.2689414213699951

# %%
sigmoid(-10)
# Out:
# 4.539786870243442e-05

# %%
sigmoid(-2.0)
# Out:
# 0.11920292202211757
